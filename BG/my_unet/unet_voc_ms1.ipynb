# %%
# !pwd
# Out:
# /home/kimbg/SPN

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"]="1";

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import cv2
import tensorflow as tf
import glob

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

print('tensorflow version :', tf.__version__)
print('TF GPU available test :', tf.test.is_gpu_available())
# Out:
# tensorflow version : 2.1.0
# WARNING:tensorflow:From <ipython-input-1-33635406a342>:17: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# TF GPU available test : True

# %% [markdown]
# ## 0. 각종 사용자 변수 정의

# %%
VOC_COLORMAP = [[0, 0, 0], [128, 0, 0], [0, 128, 0], [128, 128, 0],
                [0, 0, 128], [128, 0, 128], [0, 128, 128], [128, 128, 128],
                [64, 0, 0], [192, 0, 0], [64, 128, 0], [192, 128, 0],
                [64, 0, 128], [192, 0, 128], [64, 128, 128], [192, 128, 128],
                [0, 64, 0], [128, 64, 0], [0, 192, 0], [128, 192, 0],
                [0, 64, 128]]

VOC_CLASSES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'potted plant', 'sheep', 'sofa', 'train', 'tv/monitor']

## 의문 ##
# 엣지 클래스도 넣어야하는거 아닌가..???

# %%
BATCH_SIZE = 8
IMG_SIZE = (256, 256, 3)


image_dataset_path = '/data1/kimbg/voc2012/SegmentationDB/image'
gt_dataset_path = '/data1/kimbg/voc2012/SegmentationClass'

# %%
img_dataset_abspath = sorted(glob.glob(os.path.join(image_dataset_path, '*')))
mask_dataset_abspath = sorted(glob.glob(os.path.join(gt_dataset_path, '*')))
print(f'이미지 갯수 : {len(img_dataset_abspath)}')
print(f'마스크 갯수 : {len(mask_dataset_abspath)}')
print(list(map(os.path.basename, img_dataset_abspath))[:3])
print(list(map(os.path.basename, mask_dataset_abspath))[:3])
# Out:
# 이미지 갯수 : 2913
# 마스크 갯수 : 2913
# ['2007_000032.jpg', '2007_000033.jpg', '2007_000039.jpg']
# ['2007_000032.png', '2007_000033.png', '2007_000039.png']

# %%
def img_show(path):
    # img = plt.imread(path)
    # img1 = plt.imshow(img)
    img = cv2.imread(path)
    img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # 무조건 RGB로 읽어야 VOC_CLASSES랑 매치가 가능함. Image.open으로 파일 열고 np.array화해서 보면 클래스 세부내용 확인가능.
    plt.imshow(img1)
    print(img1.shape)

    
# 채널별로 나눠진 클래스 마스크를 시각화.
def display_multiple_img(mask1, VOC_CLASSES, rows = 1, cols=1):
    figure, ax = plt.subplots(nrows=rows, ncols=cols)
    for label, i in zip(VOC_CLASSES, range(rows*cols)):
#         print(label)
        ax.ravel()[i].imshow(mask1[:,:,i], cmap='gray')
        ax.ravel()[i].set_title(label)
        ax.ravel()[i].set_axis_off()
    plt.tight_layout()
    plt.show()


# 마스크를 클래스에 맵핑하여 클래스갯수만큼 depth생성
def mk_seg_mask(gt_path, VOC_COLORMAP):
    gt1_cv2 = cv2.imread(gt_path)
    mask = cv2.cvtColor(gt1_cv2, cv2.COLOR_BGR2RGB)
    height, width = mask.shape[:2]
    segmentation_mask = np.zeros((height, width, len(VOC_COLORMAP)), dtype=np.float32)
    for label_index, label in enumerate(VOC_COLORMAP):
    #     print(label_index, label)
        segmentation_mask[:, :, label_index] = np.all(mask == label, axis=-1).astype(float)
    return segmentation_mask


# 학습용 이미지, 마스크 생성(categorical_crossentropy)
def img_mask_set(img_path, mask_path, VOC_COLORMAP):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE[0], IMG_SIZE[1]), cv2.INTER_LINEAR)/255
    img = np.array(img, dtype=np.float32)
    
    mask = cv2.imread(mask_path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
    mask = cv2.resize(mask, (IMG_SIZE[0], IMG_SIZE[1]), cv2.INTER_LINEAR)
    
    height, width = mask.shape[:2]
    segmentation_mask = np.zeros((height, width, len(VOC_COLORMAP)), dtype=np.uint8)
    for label_index, label in enumerate(VOC_COLORMAP):
        segmentation_mask[:, :, label_index] = np.all(mask == label, axis=-1).astype(np.uint8)
    
    mask = np.array(mask/255, dtype=np.float32)
    
    return img, segmentation_mask, mask


# 학습 데이터셋(이미지, 마스크)를 구성
def dataset(img_dataset_abspath, mask_dataset_abspath, start_cnt, BATCH_SIZE):
#     start_cnt = 0

    batch_img = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], 3))
    batch_seg_mask = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], len(VOC_CLASSES)))
    batch_mask = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], 3))

    batch_img_path = img_dataset_abspath[start_cnt:BATCH_SIZE]
    batch_img_path = sorted(glob.glob(os.path.join(img_dataset_abspath, '*')))
#     print(batch_img_path)
#     batch_seg_mask_path = mask_dataset_abspath[start_cnt:BATCH_SIZE]
    batch_seg_mask_path = sorted(glob.glob(os.path.join(mask_dataset_abspath, '*')))

    for bat in range(BATCH_SIZE):
        img_b, seg_mask_b, mask_b = img_mask_set(batch_img_path[bat], batch_seg_mask_path[bat], VOC_COLORMAP)
        batch_img[bat] = img_b
        batch_seg_mask[bat] = seg_mask_b
        batch_mask[bat] = mask_b
        
    return batch_img, batch_seg_mask, batch_mask

# %% [markdown]
# ## 1. 이미지 확인

# %%
DATASET_IMG, DATASET_SEG_MASK, DATASET_MASK = dataset(image_dataset_path, gt_dataset_path, 0, 100)
print(DATASET_IMG.shape, DATASET_SEG_MASK.shape, DATASET_MASK.shape)
# Out:
# (100, 256, 256, 3) (100, 256, 256, 21) (100, 256, 256, 3)

# %%
plt.imshow(DATASET_IMG[0])

# %%
plt.imshow(DATASET_MASK[0])

# %%
display_multiple_img(DATASET_SEG_MASK[0], VOC_CLASSES, 3, 7)

# %% [markdown]
# ## 2. 모델 구성

# %%
def unet(target_size=(256,256,3)):

    IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS = target_size[0], target_size[1], target_size[2]

    #Build the model
    inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
#     s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

    #Contraction path
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = tf.keras.layers.Dropout(0.1)(c1)
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = tf.keras.layers.Dropout(0.1)(c2)
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
    
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = tf.keras.layers.Dropout(0.2)(c3)
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = tf.keras.layers.Dropout(0.2)(c4)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
    
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = tf.keras.layers.Dropout(0.3)(c5)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path 
    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = tf.keras.layers.Dropout(0.2)(c6)
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
    
    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = tf.keras.layers.Dropout(0.2)(c7)
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = tf.keras.layers.Dropout(0.1)(c8)
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
    
    u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = tf.keras.layers.Dropout(0.1)(c9)
    c9 = tf.keras.layers.Conv2D(21, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
    
    outputs = tf.keras.layers.Conv2D(21, (1, 1), activation='softmax')(c9)
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])

    return model

# %%
model = unet(IMG_SIZE)
# model.summary()

# %% [markdown]
# ## 3. 모델 컴파일

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy")

weight_path = "/home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5"

callback = [
#              tf.keras.callbacks.EarlyStopping(patience=30, monitor='val_loss'),
#              tf.keras.callbacks.TensorBoard(log_dir='logs'),
             tf.keras.callbacks.ModelCheckpoint(weight_path, verbose=1, save_best_only=False)
             ]

# %% [markdown]
# ## 4. 모델 학습

# %%
results = model.fit(DATASET_IMG, DATASET_SEG_MASK, 
                    validation_split=0.1, batch_size=3, epochs=500, callbacks=callback)
# Out:
# Train on 90 samples, validate on 10 samples
# Epoch 1/500
# 87/90 [============================>.] - ETA: 0s - loss: 2.0469
# Epoch 00001: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 15s 164ms/sample - loss: 2.0202 - val_loss: 1.7079
# Epoch 2/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.4457
# Epoch 00002: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.4230 - val_loss: 1.3154
# Epoch 3/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.2665
# Epoch 00003: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.2492 - val_loss: 1.2653
# Epoch 4/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.2172
# Epoch 00004: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 15ms/sample - loss: 1.2070 - val_loss: 1.2456
# Epoch 5/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1790
# Epoch 00005: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 16ms/sample - loss: 1.1841 - val_loss: 1.3039
# Epoch 6/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1787
# Epoch 00006: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 2s 18ms/sample - loss: 1.1837 - val_loss: 1.2496
# Epoch 7/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.2045
# Epoch 00007: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 2s 19ms/sample - loss: 1.2053 - val_loss: 1.2516
# Epoch 8/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1823
# Epoch 00008: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 16ms/sample - loss: 1.
500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0457
# Epoch 00465: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0445 - val_loss: 2.9140
# Epoch 466/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0398
# Epoch 00466: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0397 - val_loss: 2.8325
# Epoch 467/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0362
# Epoch 00467: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0361 - val_loss: 2.8737
# Epoch 468/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0335
# Epoch 00468: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0343 - val_loss: 3.0272
# Epoch 469/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0316
# Epoch 00469: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0317 - val_loss: 3.0189
# Epoch 470/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0306
# Epoch 00470: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0306 - val_loss: 2.9831
# Epoch 471/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0301
# Epoch 00471: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0298 - val_loss: 2.9588
# Epoch 472/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0289
# Epoch 00472: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0290 - val_loss: 3.0059
# Epoch 473/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0307
# Epoch 00473: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0301 - val_loss: 3.0401
# Epoch 474/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0304
# Epoch 00474: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0306 - val_loss: 2.9946
# Epoch 475/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0285
# Epoch 00475: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0284 - val_loss: 3.0611
# Epoch 476/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0265
# Epoch 00476: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0263 - val_loss: 3.0783
# Epoch 477/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0260
# Epoch 00477: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0263 - val_loss: 3.0100
# Epoch 478/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0250
# Epoch 00478: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0246 - val_loss: 3.0820
# Epoch 479/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0248
# Epoch 00479: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0244 - val_loss: 3.1206
# Epoch 480/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0235
# Epoch 00480: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0237 - val_loss: 3.1126
# Epoch 481/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0237
# Epoch 00481: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0237 - val_loss: 3.1092
# Epoch 482/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 00482: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0238 - val_loss: 3.2089
# Epoch 483/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0220
# Epoch 00483: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0216 - val_loss: 3.1141
# Epoch 484/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0213
# Epoch 00484: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0220 - val_loss: 3.1889
# Epoch 485/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0227
# Epoch 00485: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0225 - val_loss: 3.0698
# Epoch 486/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0203
# Epoch 00486: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0218 - val_loss: 3.1859
# Epoch 487/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0219
# Epoch 00487: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0217 - val_loss: 3.1174
# Epoch 488/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0208
# Epoch 00488: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0215 - val_loss: 3.1153
# Epoch 489/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0232
# Epoch 00489: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0229 - val_loss: 3.2038
# Epoch 490/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0212
# Epoch 00490: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0219 - val_loss: 3.2552
# Epoch 491/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0204
# Epoch 00491: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0207 - val_loss: 3.1575
# Epoch 492/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0202
# Epoch 00492: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0200 - val_loss: 3.1291
# Epoch 493/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0215
# Epoch 00493: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0211 - val_loss: 3.1272
# Epoch 494/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0210
# Epoch 00494: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0206 - val_loss: 3.1456
# Epoch 495/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0210
# Epoch 00495: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0206 - val_loss: 3.1208
# Epoch 496/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0193
# Epoch 00496: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 15ms/sample - loss: 0.0190 - val_loss: 3.1847
# Epoch 497/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0190
# Epoch 00497: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0186 - val_loss: 3.1409
# Epoch 498/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0176
# Epoch 00498: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 15ms/sample - loss: 0.0183 - val_loss: 3.1775
# Epoch 499/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0180
# Epoch 00499: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0176 - val_loss: 3.1604
# Epoch 500/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0178
# Epoch 00500: saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.0176 - val_loss: 3.2672

# %% [markdown]
# ## 5. 결과확인

# %%
pred = model.predict(DATASET_IMG[:1])
print(pred.shape)
display_multiple_img(pred[0], VOC_CLASSES, 3, 7)
# Out:
# (1, 256, 256, 21)

# %%
display_multiple_img(DATASET_SEG_MASK[0], VOC_CLASSES, 3, 7)

# %% [markdown]
# ## 6. 모델 불러오기

# %%
# 모델 불러오기
from tensorflow.keras import models
model_path = '/home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5'
model = models.load_model(model_path)

# %%
test_img = DATASET_IMG[:1]
pred = model.predict(test_img)

# %%
pred.shape
# Out:
# (1, 256, 256, 21)
