# %%
# !pwd
# Out:
# /home/kimbg/SPN

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"]="1";

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import cv2
import tensorflow as tf
import glob

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

print('tensorflow version :', tf.__version__)
print('TF GPU available test :', tf.test.is_gpu_available())
# Out:
# tensorflow version : 2.1.0
# WARNING:tensorflow:From <ipython-input-2-33635406a342>:17: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# TF GPU available test : True

# %% [markdown]
# 0. 각종 사용자 변수 정의
#
# 2. 마스크 확인
# 3. 마스크를 학습용 마스크로 변환
# 4. 변환된 마스크 확인
# 5.

# %% [markdown]
# ## 0. 각종 사용자 변수 정의

# %%
VOC_COLORMAP = [[0, 0, 0], [128, 0, 0], [0, 128, 0], [128, 128, 0],
                [0, 0, 128], [128, 0, 128], [0, 128, 128], [128, 128, 128],
                [64, 0, 0], [192, 0, 0], [64, 128, 0], [192, 128, 0],
                [64, 0, 128], [192, 0, 128], [64, 128, 128], [192, 128, 128],
                [0, 64, 0], [128, 64, 0], [0, 192, 0], [128, 192, 0],
                [0, 64, 128]]

VOC_CLASSES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'potted plant', 'sheep', 'sofa', 'train', 'tv/monitor']

## 의문 ##
# 엣지 클래스도 넣어야하는거 아닌가..???

# %%
BATCH_SIZE = 8
IMG_SIZE = (256, 256, 3)


image_dataset_path = '/data1/kimbg/voc2012/SegmentationDB/image'
gt_dataset_path = '/data1/kimbg/voc2012/SegmentationClass'

# %%
img_dataset_abspath = sorted(glob.glob(os.path.join(image_dataset_path, '*')))
mask_dataset_abspath = sorted(glob.glob(os.path.join(gt_dataset_path, '*')))
print(f'이미지 갯수 : {len(img_dataset_abspath)}')
print(f'마스크 갯수 : {len(mask_dataset_abspath)}')
print(list(map(os.path.basename, img_dataset_abspath))[:3])
print(list(map(os.path.basename, mask_dataset_abspath))[:3])
# Out:
# 이미지 갯수 : 2913
# 마스크 갯수 : 2913
# ['2007_000032.jpg', '2007_000033.jpg', '2007_000039.jpg']
# ['2007_000032.png', '2007_000033.png', '2007_000039.png']

# %%
def img_show(path):
    # img = plt.imread(path)
    # img1 = plt.imshow(img)
    img = cv2.imread(path)
    img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # 무조건 RGB로 읽어야 VOC_CLASSES랑 매치가 가능함. Image.open으로 파일 열고 np.array화해서 보면 클래스 세부내용 확인가능.
    plt.imshow(img1)
    print(img1.shape)

    
# 채널별로 나눠진 클래스 마스크를 시각화.
def display_multiple_img(mask1, VOC_CLASSES, rows = 1, cols=1):
    figure, ax = plt.subplots(nrows=rows, ncols=cols)
    for label, i in zip(VOC_CLASSES, range(rows*cols)):
#         print(label)
        ax.ravel()[i].imshow(mask1[:,:,i], cmap='gray')
        ax.ravel()[i].set_title(label)
        ax.ravel()[i].set_axis_off()
    plt.tight_layout()
    plt.show()


# 마스크를 클래스에 맵핑하여 클래스갯수만큼 depth생성
def mk_seg_mask(gt_path, VOC_COLORMAP):
    gt1_cv2 = cv2.imread(gt_path)
    mask = cv2.cvtColor(gt1_cv2, cv2.COLOR_BGR2RGB)
    height, width = mask.shape[:2]
    segmentation_mask = np.zeros((height, width, len(VOC_COLORMAP)), dtype=np.float32)
    for label_index, label in enumerate(VOC_COLORMAP):
    #     print(label_index, label)
        segmentation_mask[:, :, label_index] = np.all(mask == label, axis=-1).astype(float)
    return segmentation_mask


# 학습용 이미지, 마스크 생성(categorical_crossentropy)
def img_mask_set(img_path, mask_path, VOC_COLORMAP):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE[0], IMG_SIZE[1]), cv2.INTER_LINEAR)/255
    img = np.array(img, dtype=np.float32)
    
    mask = cv2.imread(mask_path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
    mask = cv2.resize(mask, (IMG_SIZE[0], IMG_SIZE[1]), cv2.INTER_LINEAR)
    
    height, width = mask.shape[:2]
    segmentation_mask = np.zeros((height, width, len(VOC_COLORMAP)), dtype=np.uint8)
    for label_index, label in enumerate(VOC_COLORMAP):
        segmentation_mask[:, :, label_index] = np.all(mask == label, axis=-1).astype(np.uint8)
    
    mask = np.array(mask/255, dtype=np.float32)
    
    return img, segmentation_mask, mask


# 학습 데이터셋(이미지, 마스크)를 구성
def dataset(img_dataset_abspath, mask_dataset_abspath, start_cnt, BATCH_SIZE):
#     start_cnt = 0

    batch_img = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], 3))
    batch_seg_mask = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], len(VOC_CLASSES)))
    batch_mask = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], 3))

    batch_img_path = img_dataset_abspath[start_cnt:BATCH_SIZE]
    batch_img_path = sorted(glob.glob(os.path.join(img_dataset_abspath, '*')))
#     print(batch_img_path)
#     batch_seg_mask_path = mask_dataset_abspath[start_cnt:BATCH_SIZE]
    batch_seg_mask_path = sorted(glob.glob(os.path.join(mask_dataset_abspath, '*')))

    for bat in range(BATCH_SIZE):
        img_b, seg_mask_b, mask_b = img_mask_set(batch_img_path[bat], batch_seg_mask_path[bat], VOC_COLORMAP)
        batch_img[bat] = img_b
        batch_seg_mask[bat] = seg_mask_b
        batch_mask[bat] = mask_b
        
    return batch_img, batch_seg_mask, batch_mask

# %% [markdown]
# ## 1. 이미지 확인

# %%
DATASET_IMG, DATASET_SEG_MASK, DATASET_MASK = dataset(image_dataset_path, gt_dataset_path, 0, 100)
print(DATASET_IMG.shape, DATASET_SEG_MASK.shape, DATASET_MASK.shape)
# Out:
# (100, 256, 256, 3) (100, 256, 256, 21) (100, 256, 256, 3)

# %%
plt.imshow(DATASET_IMG[0])

# %%
plt.imshow(DATASET_MASK[0])

# %%
display_multiple_img(DATASET_SEG_MASK[0], VOC_CLASSES, 3, 7)

# %% [markdown]
# ## 2. 모델 구성

# %%
def unet(target_size=(256,256,3)):

    IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS = target_size[0], target_size[1], target_size[2]

    #Build the model
    inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

    #Contraction path
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = tf.keras.layers.Dropout(0.1)(c1)
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = tf.keras.layers.Dropout(0.1)(c2)
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
    
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = tf.keras.layers.Dropout(0.2)(c3)
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = tf.keras.layers.Dropout(0.2)(c4)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
    
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = tf.keras.layers.Dropout(0.3)(c5)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path 
    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = tf.keras.layers.Dropout(0.2)(c6)
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
    
    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = tf.keras.layers.Dropout(0.2)(c7)
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = tf.keras.layers.Dropout(0.1)(c8)
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
    
    u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = tf.keras.layers.Dropout(0.1)(c9)
    c9 = tf.keras.layers.Conv2D(21, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
    
    outputs = tf.keras.layers.Conv2D(21, (1, 1), activation='softmax')(c9)
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])

    return model

# %%
model = unet(IMG_SIZE)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 16) 448         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 256, 256, 16) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 16) 2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128, 32) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 9248        dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 64)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   36928       dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 128)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 128)  147584      dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 256)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  590080      dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 128)  131200      conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_4[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 128)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 128)  147584      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 64)   32832       conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 64)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 64)   36928       dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 32) 8224        conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_6[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 32) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 32) 9248        dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 16) 2064        conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 256, 256, 16) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 21) 3045        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 21) 462         conv2d_36[0][0]
# ==================================================================================================
# Total params: 1,942,275
# Trainable params: 1,942,275
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy")

weight_path = "/home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5"

callback = [
#              tf.keras.callbacks.EarlyStopping(patience=30, monitor='val_loss'),
#              tf.keras.callbacks.TensorBoard(log_dir='logs'),
             tf.keras.callbacks.ModelCheckpoint(weight_path, verbose=1, save_best_only=True)
             ]

# %%
results = model.fit(DATASET_IMG, DATASET_SEG_MASK, 
                    validation_split=0.1, batch_size=3, epochs=500, callbacks=callback)
# Out:
# Train on 90 samples, validate on 10 samples
# Epoch 1/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1396
# Epoch 00001: val_loss improved from inf to 1.20879, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 4s 45ms/sample - loss: 1.1316 - val_loss: 1.2088
# Epoch 2/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1127
# Epoch 00002: val_loss did not improve from 1.20879
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1157 - val_loss: 1.2248
# Epoch 3/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1372
# Epoch 00003: val_loss improved from 1.20879 to 1.20475, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 16ms/sample - loss: 1.1244 - val_loss: 1.2047
# Epoch 4/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1077
# Epoch 00004: val_loss improved from 1.20475 to 1.19911, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 2s 17ms/sample - loss: 1.1196 - val_loss: 1.1991
# Epoch 5/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1238
# Epoch 00005: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1258 - val_loss: 1.2111
# Epoch 6/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1185
# Epoch 00006: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1223 - val_loss: 1.2188
# Epoch 7/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1929
# Epoch 00007: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1564 - val_loss: 1.2387
# Epoch 8/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1617
# Epoch 00008: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1508 - val_loss: 1.2372
# Epoch 9/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1295
# Epoch 00009: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1347 - val_loss: 1.2081
# Epoch 10/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1205
# Epoch 00010: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1338 - val_loss: 1.2362
# Epoch 11/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1443
# Epoch 00011: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1361 - val_loss: 1.2173
# Epoch 12/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1424
# Epoch 00012: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 16ms/sample - loss: 1.1505 - val_loss: 1.2393
# Epoch 13/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1576
# Epoch 00013: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1412 - val_loss: 1.2388
# Epoch 14/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1523
# Epoch 00014: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1481 - val_loss: 1.2189
# Epoch 15/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1259
# Epoch 00015: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1310 - val_loss: 1.2106
# Epoch 16/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1396
# Epoch 00016: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1363 - val_loss: 1.2104
# Epoch 17/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1266
# Epoch 00017: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1307 - val_loss: 1.2128
# Epoch 18/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1298
# Epoch 00018: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 15ms/sample - loss: 1.1196 - val_loss: 1.2149
# Epoch 19/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1141
# Epoch 00019: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1172 - val_loss: 1.2247
# Epoch 20/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1076
# Epoch 00020: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1199 - val_loss: 1.2137
# Epoch 21/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1040
# Epoch 00021: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1152 - val_loss: 1.2168
# Epoch 22/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1224
# Epoch 00022: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1187 - val_loss: 1.2053
# Epoch 23/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0968
# Epoch 00023: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1109 - val_loss: 1.2171
# Epoch 24/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1302
# Epoch 00024: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1239 - val_loss: 1.2291
# Epoch 25/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1343
# Epoch 00025: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1248 - val_loss: 1.2078
# Epoch 26/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1103
# Epoch 00026: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1140 - val_loss: 1.2054
# Epoch 27/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0610
# Epoch 00027: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1118 - val_loss: 1.2272
# Epoch 28/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1203
# Epoch 00028: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1207 - val_loss: 1.2041
# Epoch 29/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0905
# Epoch 00029: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1076 - val_loss: 1.2146
# Epoch 30/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1053
# Epoch 00030: val_loss did not improve from 1.19911
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1049 - val_loss: 1.2031
# Epoch 31/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0962
# Epoch 00031: val_loss improved from 1.19911 to 1.19469, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 15ms/sample - loss: 1.1047 - val_loss: 1.1947
# Epoch 32/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1149
# Epoch 00032: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1169 - val_loss: 1.2300
# Epoch 33/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0903
# Epoch 00033: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1033 - val_loss: 1.2114
# Epoch 34/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1240
# Epoch 00034: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1202 - val_loss: 1.2329
# Epoch 35/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1222
# Epoch 00035: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1083 - val_loss: 1.2336
# Epoch 36/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0886
# Epoch 00036: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0977 - val_loss: 1.2190
# Epoch 37/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.1016
# Epoch 00037: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0963 - val_loss: 1.1951
# Epoch 38/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1142
# Epoch 00038: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0995 - val_loss: 1.2012
# Epoch 39/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0829
# Epoch 00039: val_loss did not improve from 1.19469
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0911 - val_loss: 1.2199
# Epoch 40/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0808
# Epoch 00040: val_loss improved from 1.19469 to 1.19032, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 15ms/sample - loss: 1.0830 - val_loss: 1.1903
# Epoch 41/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0785
# Epoch 00041: val_loss did not improve from 1.19032
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0811 - val_loss: 1.2319
# Epoch 42/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0919
# Epoch 00042: val_loss improved from 1.19032 to 1.18559, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 15ms/sample - loss: 1.0810 - val_loss: 1.1856
# Epoch 43/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0914
# Epoch 00043: val_loss improved from 1.18559 to 1.17952, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 16ms/sample - loss: 1.0811 - val_loss: 1.1795
# Epoch 44/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0602
# Epoch 00044: val_loss did not improve from 1.17952
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0595 - val_loss: 1.2201
# Epoch 45/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0881
# Epoch 00045: val_loss did not improve from 1.17952
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0806 - val_loss: 1.2034
# Epoch 46/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0852
# Epoch 00046: val_loss did not improve from 1.17952
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0698 - val_loss: 1.2121
# Epoch 47/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0769
# Epoch 00047: val_loss did not improve from 1.17952
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0590 - val_loss: 1.1816
# Epoch 48/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0685
# Epoch 00048: val_loss did not improve from 1.17952
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0661 - val_loss: 1.2535
# Epoch 49/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0707
# Epoch 00049: val_loss did not improve from 1.17952
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0589 - val_loss: 1.1841
# Epoch 50/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0394
# Epoch 00050: val_loss improved from 1.17952 to 1.16264, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.0462 - val_loss: 1.1626
# Epoch 51/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0824
# Epoch 00051: val_loss did not improve from 1.16264
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0989 - val_loss: 1.1937
# Epoch 52/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0548
# Epoch 00052: val_loss did not improve from 1.16264
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0400 - val_loss: 1.2052
# Epoch 53/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0209
# Epoch 00053: val_loss did not improve from 1.16264
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0410 - val_loss: 1.1913
# Epoch 54/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0719
# Epoch 00054: val_loss did not improve from 1.16264
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0537 - val_loss: 1.1929
# Epoch 55/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0287
# Epoch 00055: val_loss did not improve from 1.16264
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0381 - val_loss: 1.1860
# Epoch 56/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0175
# Epoch 00056: val_loss did not improve from 1.16264
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0302 - val_loss: 1.1648
# Epoch 57/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0266
# Epoch 00057: val_loss did not improve from 1.16264
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0204 - val_loss: 1.1928
# Epoch 58/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0194
# Epoch 00058: val_loss improved from 1.16264 to 1.14495, saving model to /home/kimbg/SPN/Colab Notebooks/MyUnet/weight/model_for_nuclei_2.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.0193 - val_loss: 1.1449
# Epoch 59/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0358
# Epoch 00059: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0230 - val_loss: 1.1596
# Epoch 60/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.0070
# Epoch 00060: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0124 - val_loss: 1.2368
# Epoch 61/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9829
# Epoch 00061: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0078 - val_loss: 1.2077
# Epoch 62/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0259
# Epoch 00062: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0066 - val_loss: 1.2530
# Epoch 63/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.9945
# Epoch 00063: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 14ms/sample - loss: 0.9887 - val_loss: 1.1940
# Epoch 64/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9947
# Epoch 00064: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9850 - val_loss: 1.2213
# Epoch 65/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.9748
# Epoch 00065: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9786 - val_loss: 1.1568
# Epoch 66/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9916
# Epoch 00066: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 15ms/sample - loss: 0.9841 - val_loss: 1.1688
# Epoch 67/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9862
# Epoch 00067: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9735 - val_loss: 1.4146
# Epoch 68/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9820
# Epoch 00068: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9784 - val_loss: 1.2447
# Epoch 69/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9193
# Epoch 00069: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9382 - val_loss: 1.1838
# Epoch 70/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9406
# Epoch 00070: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.9286 - val_loss: 1.1721
# Epoch 71/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9522
# Epoch 00071: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9629 - val_loss: 1.1889
# Epoch 72/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9350
# Epoch 00072: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9596 - val_loss: 1.3697
# Epoch 73/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9075
# Epoch 00073: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9133 - val_loss: 1.2748
# Epoch 74/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8581
# Epoch 00074: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.8913 - val_loss: 1.2353
# Epoch 75/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.
val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1580 - val_loss: 2.9053
# Epoch 198/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1570
# Epoch 00198: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1551 - val_loss: 2.8829
# Epoch 199/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1439
# Epoch 00199: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1480 - val_loss: 2.8978
# Epoch 200/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1603
# Epoch 00200: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1585 - val_loss: 2.7805
# Epoch 201/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1442
# Epoch 00201: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1461 - val_loss: 2.9074
# Epoch 202/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1372
# Epoch 00202: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1370 - val_loss: 2.7683
# Epoch 203/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1328
# Epoch 00203: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1332 - val_loss: 2.7631
# Epoch 204/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1265
# Epoch 00204: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1275 - val_loss: 2.8199
# Epoch 205/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1201
# Epoch 00205: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1199 - val_loss: 2.9833
# Epoch 206/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1206
# Epoch 00206: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1214 - val_loss: 2.8562
# Epoch 207/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1400
# Epoch 00207: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1464 - val_loss: 2.7644
# Epoch 208/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1533
# Epoch 00208: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1579 - val_loss: 2.8256
# Epoch 209/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1653
# Epoch 00209: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1652 - val_loss: 2.8418
# Epoch 210/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1506
# Epoch 00210: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1502 - val_loss: 2.7397
# Epoch 211/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1323
# Epoch 00211: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1302 - val_loss: 2.9329
# Epoch 212/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1266
# Epoch 00212: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1260 - val_loss: 2.8182
# Epoch 213/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1127
# Epoch 00213: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1144 - val_loss: 2.8910
# Epoch 214/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1145
# Epoch 00214: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.1148 - val_loss: 2.7754
# Epoch 215/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1297
# Epoch 00215: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1291 - val_loss: 2.8041
# Epoch 216/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1538
# Epoch 00216: val_loss did not improve from 1.14495
# ...
# Epoch 428/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 00428: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0174 - val_loss: 3.1252
# Epoch 429/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0183
# Epoch 00429: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0182 - val_loss: 3.0912
# Epoch 430/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 00430: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0177 - val_loss: 3.1479
# Epoch 431/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0194
# Epoch 00431: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0194 - val_loss: 3.1959
# Epoch 432/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0180
# Epoch 00432: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0184 - val_loss: 3.1352
# Epoch 433/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0161
# Epoch 00433: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0166 - val_loss: 3.1807
# Epoch 434/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0168
# Epoch 00434: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0170 - val_loss: 3.1380
# Epoch 435/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0163
# Epoch 00435: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0164 - val_loss: 3.1614
# Epoch 436/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0160
# Epoch 00436: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0161 - val_loss: 3.2413
# Epoch 437/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 00437: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0162 - val_loss: 3.1961
# Epoch 438/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0163
# Epoch 00438: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0165 - val_loss: 3.1964
# Epoch 439/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 00439: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0162 - val_loss: 3.2310
# Epoch 440/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0158
# Epoch 00440: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0160 - val_loss: 3.2116
# Epoch 441/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0144
# Epoch 00441: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0148 - val_loss: 3.2203
# Epoch 442/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 00442: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0165 - val_loss: 3.1867
# Epoch 443/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 00443: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0179 - val_loss: 3.1719
# Epoch 444/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0179
# Epoch 00444: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0182 - val_loss: 3.2043
# Epoch 445/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0176
# Epoch 00445: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0174 - val_loss: 3.1418
# Epoch 446/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 00446: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0153 - val_loss: 3.2128
# Epoch 447/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 00447: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0162 - val_loss: 3.1339
# Epoch 448/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0145
# Epoch 00448: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0146 - val_loss: 3.2006
# Epoch 449/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0144
# Epoch 00449: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0144 - val_loss: 3.1548
# Epoch 450/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0163
# Epoch 00450: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0166 - val_loss: 3.0693
# Epoch 451/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0146
# Epoch 00451: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0148 - val_loss: 3.1952
# Epoch 452/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0140
# Epoch 00452: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0143 - val_loss: 3.2091
# Epoch 453/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0148
# Epoch 00453: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0147 - val_loss: 3.1707
# Epoch 454/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0145
# Epoch 00454: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0143 - val_loss: 3.1635
# Epoch 455/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 00455: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0164 - val_loss: 3.2135
# Epoch 456/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0140
# Epoch 00456: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0143 - val_loss: 3.2494
# Epoch 457/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 00457: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0153 - val_loss: 3.2933
# Epoch 458/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0165
# Epoch 00458: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0159 - val_loss: 3.2919
# Epoch 459/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 00459: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0164 - val_loss: 3.2518
# Epoch 460/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0185
# Epoch 00460: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0194 - val_loss: 3.1795
# Epoch 461/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 00461: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0175 - val_loss: 3.1265
# Epoch 462/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0155
# Epoch 00462: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0156 - val_loss: 3.1915
# Epoch 463/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0160
# Epoch 00463: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0158 - val_loss: 3.2090
# Epoch 464/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0186
# Epoch 00464: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0183 - val_loss: 3.1207
# Epoch 465/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0210
# Epoch 00465: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0226 - val_loss: 3.1564
# Epoch 466/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0591
# Epoch 00466: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0607 - val_loss: 3.0039
# Epoch 467/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2414
# Epoch 00467: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.2379 - val_loss: 2.3982
# Epoch 468/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2712
# Epoch 00468: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.2723 - val_loss: 2.2462
# Epoch 469/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2725
# Epoch 00469: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.2706 - val_loss: 2.3844
# Epoch 470/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2754
# Epoch 00470: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.2745 - val_loss: 2.1425
# Epoch 471/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2648
# Epoch 00471: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.2618 - val_loss: 2.4322
# Epoch 472/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.1587
# Epoch 00472: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.1586 - val_loss: 2.7110
# Epoch 473/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.1205
# Epoch 00473: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1176 - val_loss: 2.7707
# Epoch 474/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0787
# Epoch 00474: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0777 - val_loss: 2.9272
# Epoch 475/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0595
# Epoch 00475: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0582 - val_loss: 2.8254
# Epoch 476/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0497
# Epoch 00476: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0491 - val_loss: 2.9426
# Epoch 477/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0359
# Epoch 00477: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0359 - val_loss: 3.0228
# Epoch 478/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0337
# Epoch 00478: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0332 - val_loss: 3.0698
# Epoch 479/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0291
# Epoch 00479: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0295 - val_loss: 3.1134
# Epoch 480/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0264
# Epoch 00480: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0262 - val_loss: 3.0687
# Epoch 481/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0226
# Epoch 00481: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0234 - val_loss: 3.0285
# Epoch 482/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0231
# Epoch 00482: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0232 - val_loss: 3.0392
# Epoch 483/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0208
# Epoch 00483: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0204 - val_loss: 3.1368
# Epoch 484/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0193
# Epoch 00484: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0197 - val_loss: 3.0718
# Epoch 485/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0192
# Epoch 00485: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0190 - val_loss: 3.0853
# Epoch 486/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0180
# Epoch 00486: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0181 - val_loss: 3.1040
# Epoch 487/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0186
# Epoch 00487: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0187 - val_loss: 3.1043
# Epoch 488/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 00488: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0181 - val_loss: 3.1299
# Epoch 489/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 00489: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0164 - val_loss: 3.1091
# Epoch 490/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 00490: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0161 - val_loss: 3.1279
# Epoch 491/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0158
# Epoch 00491: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0160 - val_loss: 3.1437
# Epoch 492/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0153
# Epoch 00492: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0157 - val_loss: 3.1066
# Epoch 493/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0144
# Epoch 00493: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0145 - val_loss: 3.1453
# Epoch 494/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0151
# Epoch 00494: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0149 - val_loss: 3.1403
# Epoch 495/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0143
# Epoch 00495: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0145 - val_loss: 3.1621
# Epoch 496/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0134
# Epoch 00496: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0136 - val_loss: 3.1573
# Epoch 497/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0138
# Epoch 00497: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0136 - val_loss: 3.1933
# Epoch 498/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0128
# Epoch 00498: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0132 - val_loss: 3.1638
# Epoch 499/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0140
# Epoch 00499: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0140 - val_loss: 3.1598
# Epoch 500/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0141
# Epoch 00500: val_loss did not improve from 1.14495
# 90/90 [==============================] - 1s 11ms/sample - loss: 0.0140 - val_loss: 3.1630

# %%
pred = model.predict(DATASET_IMG[:1])
print(pred.shape)
display_multiple_img(pred[0], VOC_CLASSES, 3, 7)
# Out:
# (1, 256, 256, 21)

# %%
display_multiple_img(DATASET_SEG_MASK[0], VOC_CLASSES, 3, 7)

# %%
sample_vec = pred[0][200][220]
print(sample_vec.shape)
print(sample_vec)
np.argmax(sample_vec)
# Out:
# (21,)
# [0.5875857  0.0144795  0.01100462 0.01289494 0.00919026 0.006711
#  0.03143212 0.01132954 0.02154358 0.01622048 0.02175937 0.03333526
#  0.00919544 0.01347379 0.01322803 0.09231371 0.00473944 0.02180125
#  0.0179406  0.02653014 0.02329139]
# 0

# %%
np.sum(pred[0][0][0])
# Out:
# 0.99999994

# %%
sum(pred[0][0][1])
# Out:
# 0.9999999328583726

# %%
sum(pred[0][0][2])
# Out:
# 0.9999999612291504

# %%
plt.imshow(DATASET_IMG[2])

# %%
from tensorflow.keras import layers
from tensorflow import keras
img_size = (256, 256)
num_classes = 21
batch_size = 3
def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %%
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 32) 0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 128, 128, 64) 2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 128, 128, 64) 4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 64, 64, 128)  8896        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 128)  512         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 64, 64, 128)  17664       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 128)  8320        add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 128)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 32, 32, 256)  34176       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 256)  1024        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 32, 32, 256)  68096       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 256)  33024       add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 256)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  65792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 256)  0           up_sampling2d[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  32896       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 128)  0           up_sampling2d_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 64)   256         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 128 0           add_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 64) 8256        up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 64) 0           up_sampling2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 32) 18464       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 32) 128         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 32) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 32) 9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 32) 128         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 2080        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 256, 32) 0           up_sampling2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 21) 6069        add_6[0][0]
# ==================================================================================================
# Total params: 2,064,181
# Trainable params: 2,060,405
# Non-trainable params: 3,776
# __________________________________________________________________________________________________
