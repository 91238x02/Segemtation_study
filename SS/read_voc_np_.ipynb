# %%
# !pwd

# %%
##########OTHER_STUFF(jupyterNotebook)#############################
#Check out Gpu setting1(in jupyter script)
import tensorflow as tf 
print(tf.test.is_built_with_cuda())  #True >> using Gpu 
print(tf.test.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None))  #True >> using Gpu
# Out:
# True
# WARNING:tensorflow:From <ipython-input-1-d1ed09e167c7>:5: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"]="1";

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import cv2
import tensorflow as tf
import glob

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

print('tensorflow version :', tf.__version__)
print('TF GPU available test :', tf.test.is_gpu_available())
# Out:
# tensorflow version : 2.1.0
# TF GPU available test : True

# %% [markdown]
# 0. 각종 사용자 변수 정의
#
# 2. 마스크 확인
# 3. 마스크를 학습용 마스크로 변환
# 4. 변환된 마스크 확인
# 5.

# %% [markdown]
# ## 0. 각종 사용자 변수 정의

# %%
VOC_COLORMAP = [[0, 0, 0], [128, 0, 0], [0, 128, 0], [128, 128, 0],
                [0, 0, 128], [128, 0, 128], [0, 128, 128], [128, 128, 128],
                [64, 0, 0], [192, 0, 0], [64, 128, 0], [192, 128, 0],
                [64, 0, 128], [192, 0, 128], [64, 128, 128], [192, 128, 128],
                [0, 64, 0], [128, 64, 0], [0, 192, 0], [128, 192, 0],
                [0, 64, 128]]

VOC_CLASSES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'potted plant', 'sheep', 'sofa', 'train', 'tv/monitor']

## 의문 ##
# 엣지 클래스도 넣어야하는거 아닌가..???

# %%
BATCH_SIZE = 8
IMG_SIZE = (256, 256, 3)

image_dataset_path = 'C:\\Users\\icecr\\OneDrive\\#Project_Segmentation\\image'
gt_dataset_path = 'C:\\Users\\icecr\\OneDrive\\#Project_Segmentation\\SegmentationClass'

# %%
img_dataset_abspath = sorted(glob.glob(os.path.join(image_dataset_path, '*')))
mask_dataset_abspath = sorted(glob.glob(os.path.join(gt_dataset_path, '*')))
print(f'이미지 갯수 : {len(img_dataset_abspath)}')
print(f'마스크 갯수 : {len(mask_dataset_abspath)}')
print(list(map(os.path.basename, img_dataset_abspath))[:3])
print(list(map(os.path.basename, mask_dataset_abspath))[:3])
# Out:
# 이미지 갯수 : 2913
# 마스크 갯수 : 2913
# ['2007_000032.jpg', '2007_000033.jpg', '2007_000039.jpg']
# ['2007_000032.png', '2007_000033.png', '2007_000039.png']

# %%
def img_show(path):
    # img = plt.imread(path)
    # img1 = plt.imshow(img)
    img = cv2.imread(path)
    img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # 무조건 RGB로 읽어야 VOC_CLASSES랑 매치가 가능함. Image.open으로 파일 열고 np.array화해서 보면 클래스 세부내용 확인가능.
    plt.imshow(img1)
    print(img1.shape)

    
# 채널별로 나눠진 클래스 마스크를 시각화.
def display_multiple_img(mask1, VOC_CLASSES, rows = 1, cols=1):
    figure, ax = plt.subplots(nrows=rows, ncols=cols)
    for label, i in zip(VOC_CLASSES, range(rows*cols)):
#         print(label)
        ax.ravel()[i].imshow(mask1[:,:,i], cmap='gray')
        ax.ravel()[i].set_title(label)
        ax.ravel()[i].set_axis_off()
    plt.tight_layout()
    plt.show()


# 마스크를 클래스에 맵핑하여 클래스갯수만큼 depth생성
def mk_seg_mask(gt_path, VOC_COLORMAP):
    gt1_cv2 = cv2.imread(gt_path)
    mask = cv2.cvtColor(gt1_cv2, cv2.COLOR_BGR2RGB)
    height, width = mask.shape[:2]
    segmentation_mask = np.zeros((height, width, len(VOC_COLORMAP)), dtype=np.float32)
    for label_index, label in enumerate(VOC_COLORMAP):
    #     print(label_index, label)
        segmentation_mask[:, :, label_index] = np.all(mask == label, axis=-1).astype(float)
    return segmentation_mask


# 학습용 이미지, 마스크 생성(categorical_crossentropy)
def img_mask_set(img_path, mask_path, VOC_COLORMAP):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE[0], IMG_SIZE[1]), cv2.INTER_LINEAR)/255
    img = np.array(img, dtype=np.float32)
    
    mask = cv2.imread(mask_path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
    mask = cv2.resize(mask, (IMG_SIZE[0], IMG_SIZE[1]), cv2.INTER_LINEAR)
    
    height, width = mask.shape[:2]
    segmentation_mask = np.zeros((height, width, len(VOC_COLORMAP)), dtype=np.uint8)
    for label_index, label in enumerate(VOC_COLORMAP):
        segmentation_mask[:, :, label_index] = np.all(mask == label, axis=-1).astype(np.uint8)
    
    mask = np.array(mask/255, dtype=np.float32)
    
    return img, segmentation_mask, mask


# 학습 데이터셋(이미지, 마스크)를 구성
def dataset(img_dataset_abspath, mask_dataset_abspath, start_cnt, BATCH_SIZE):
#     start_cnt = 0

    batch_img = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], 3))
    batch_seg_mask = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], len(VOC_CLASSES)))
    batch_mask = np.empty((BATCH_SIZE, IMG_SIZE[0], IMG_SIZE[1], 3))

    batch_img_path = img_dataset_abspath[start_cnt:BATCH_SIZE]
    batch_img_path = sorted(glob.glob(os.path.join(img_dataset_abspath, '*')))
#     print(batch_img_path)
#     batch_seg_mask_path = mask_dataset_abspath[start_cnt:BATCH_SIZE]
    batch_seg_mask_path = sorted(glob.glob(os.path.join(mask_dataset_abspath, '*')))

    for bat in range(BATCH_SIZE):
        img_b, seg_mask_b, mask_b = img_mask_set(batch_img_path[bat], batch_seg_mask_path[bat], VOC_COLORMAP)
        batch_img[bat] = img_b
        batch_seg_mask[bat] = seg_mask_b
        batch_mask[bat] = mask_b
        
    return batch_img, batch_seg_mask, batch_mask

# %% [markdown]
# ## 1. 이미지 확인

# %%
DATASET_IMG, DATASET_SEG_MASK, DATASET_MASK = dataset(image_dataset_path, gt_dataset_path, 0, 100)
print(DATASET_IMG.shape, DATASET_SEG_MASK.shape, DATASET_MASK.shape)
# Out:
# (100, 256, 256, 3) (100, 256, 256, 21) (100, 256, 256, 3)

# %%
plt.imshow(DATASET_IMG[0])

# %%
plt.imshow(DATASET_MASK[0])

# %%
display_multiple_img(DATASET_SEG_MASK[0], VOC_CLASSES, 3, 7)

# %% [markdown]
# ## 2. 모델 구성

# %%
def unet(target_size=(256,256,3)):

    IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS = target_size[0], target_size[1], target_size[2]

    #Build the model
    inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

    #Contraction path
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = tf.keras.layers.Dropout(0.1)(c1)
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = tf.keras.layers.Dropout(0.1)(c2)
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
    
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = tf.keras.layers.Dropout(0.2)(c3)
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = tf.keras.layers.Dropout(0.2)(c4)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
    
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = tf.keras.layers.Dropout(0.3)(c5)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path 
    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = tf.keras.layers.Dropout(0.2)(c6)
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
    
    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = tf.keras.layers.Dropout(0.2)(c7)
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = tf.keras.layers.Dropout(0.1)(c8)
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
    
    u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = tf.keras.layers.Dropout(0.1)(c9)
    c9 = tf.keras.layers.Conv2D(21, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
    
    outputs = tf.keras.layers.Conv2D(21, (1, 1), activation='softmax')(c9)
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])

    return model

# %%
model = unet(IMG_SIZE)
#model.summary()

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy")

weight_path = "C:\\Users\\icecr\\Desktop\\downloads\\model_1.h5"

callback = [
#              tf.keras.callbacks.EarlyStopping(patience=30, monitor='val_loss'),
#              tf.keras.callbacks.TensorBoard(log_dir='logs'),
             tf.keras.callbacks.ModelCheckpoint(weight_path, verbose=1, save_best_only=True)
             ]

# %%
results = model.fit(DATASET_IMG, DATASET_SEG_MASK, 
                    validation_split=0.1, batch_size=3, epochs=500, callbacks=callback)
# Out:
# Train on 90 samples, validate on 10 samples
# Epoch 1/500
# 87/90 [============================>.] - ETA: 0s - loss: 2.3675
# Epoch 00001: val_loss improved from inf to 1.66352, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 6s 67ms/sample - loss: 2.3823 - val_loss: 1.6635
# Epoch 2/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.4351
# Epoch 00002: val_loss improved from 1.66352 to 1.49985, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.4200 - val_loss: 1.4998
# Epoch 3/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.3155
# Epoch 00003: val_loss improved from 1.49985 to 1.37720, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.3184 - val_loss: 1.3772
# Epoch 4/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.2273
# Epoch 00004: val_loss improved from 1.37720 to 1.32981, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.2316 - val_loss: 1.3298
# Epoch 5/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.2324- ETA: 0s - lo
# Epoch 00005: val_loss did not improve from 1.32981
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.2306 - val_loss: 1.3385
# Epoch 6/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1973
# Epoch 00006: val_loss improved from 1.32981 to 1.26342, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1896 - val_loss: 1.2634
# Epoch 7/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1783
# Epoch 00007: val_loss did not improve from 1.26342
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1648 - val_loss: 1.2869
# Epoch 8/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1988
# Epoch 00008: val_loss did not improve from 1.26342
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1801 - val_loss: 1.2639
# Epoch 9/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1539
# Epoch 00009: val_loss did not improve from 1.26342
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1670 - val_loss: 1.2925
# Epoch 10/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1606
# Epoch 00010: val_loss improved from 1.26342 to 1.23420, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1489 - val_loss: 1.2342
# Epoch 11/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1598
# Epoch 00011: val_loss did not improve from 1.23420
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1498 - val_loss: 1.2362
# Epoch 12/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1597
# Epoch 00012: val_loss did not improve from 1.23420
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1510 - val_loss: 1.2527
# Epoch 13/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1636
# Epoch 00013: val_loss did not improve from 1.23420
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1494 - val_loss: 1.2766
# Epoch 14/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1968
# Epoch 00014: val_loss improved from 1.23420 to 1.23060, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1873 - val_loss: 1.2306
# Epoch 15/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1331
# Epoch 00015: val_loss did not improve from 1.23060
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1439 - val_loss: 1.2363
# Epoch 16/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1280
# Epoch 00016: val_loss improved from 1.23060 to 1.22899, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1487 - val_loss: 1.2290
# Epoch 17/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1322
# Epoch 00017: val_loss improved from 1.22899 to 1.22649, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1525 - val_loss: 1.2265
# Epoch 18/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1449
# Epoch 00018: val_loss did not improve from 1.22649
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1334 - val_loss: 1.2442
# Epoch 19/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1761
# Epoch 00019: val_loss did not improve from 1.22649
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1576 - val_loss: 1.2535
# Epoch 20/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1171
# Epoch 00020: val_loss improved from 1.22649 to 1.21755, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1307 - val_loss: 1.2176
# Epoch 21/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1057
# Epoch 00021: val_loss did not improve from 1.21755
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1336 - val_loss: 1.2176
# Epoch 22/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1330
# Epoch 00022: val_loss did not improve from 1.21755
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1289 - val_loss: 1.2198
# Epoch 23/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1239
# Epoch 00023: val_loss improved from 1.21755 to 1.21558, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1249 - val_loss: 1.2156
# Epoch 24/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1066
# Epoch 00024: val_loss did not improve from 1.21558
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1212 - val_loss: 1.2223
# Epoch 25/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1489
# Epoch 00025: val_loss did not improve from 1.21558
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1307 - val_loss: 1.2408
# Epoch 26/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1788
# Epoch 00026: val_loss did not improve from 1.21558
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1701 - val_loss: 1.2535
# Epoch 27/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1246
# Epoch 00027: val_loss improved from 1.21558 to 1.20609, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1359 - val_loss: 1.2061
# Epoch 28/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0981
# Epoch 00028: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1248 - val_loss: 1.2120
# Epoch 29/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1253
# Epoch 00029: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1241 - val_loss: 1.2184
# Epoch 30/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1439
# Epoch 00030: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1223 - val_loss: 1.2431
# Epoch 31/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1442
# Epoch 00031: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1340 - val_loss: 1.2157
# Epoch 32/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1117
# Epoch 00032: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1411 - val_loss: 1.2434
# Epoch 33/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1481
# Epoch 00033: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1283 - val_loss: 1.2177
# Epoch 34/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1357
# Epoch 00034: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1204 - val_loss: 1.2298
# Epoch 35/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1098
# Epoch 00035: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1237 - val_loss: 1.2155
# Epoch 36/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1245
# Epoch 00036: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1166 - val_loss: 1.2109
# Epoch 37/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1433
# Epoch 00037: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1288 - val_loss: 1.2419
# Epoch 38/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1342
# Epoch 00038: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1376 - val_loss: 1.2200
# Epoch 39/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0896
# Epoch 00039: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1163 - val_loss: 1.2163
# Epoch 40/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1173
# Epoch 00040: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1282 - val_loss: 1.2110
# Epoch 41/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1079
# Epoch 00041: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1200 - val_loss: 1.2251
# Epoch 42/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1162
# Epoch 00042: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1256 - val_loss: 1.2114
# Epoch 43/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1255
# Epoch 00043: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1307 - val_loss: 1.2096
# Epoch 44/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1269
# Epoch 00044: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1173 - val_loss: 1.2183
# Epoch 45/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1064
# Epoch 00045: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1202 - val_loss: 1.2203
# Epoch 46/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1096
# Epoch 00046: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1192 - val_loss: 1.2106
# Epoch 47/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1254
# Epoch 00047: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1190 - val_loss: 1.2128
# Epoch 48/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1361
# Epoch 00048: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1402 - val_loss: 1.2419
# Epoch 49/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1538
# Epoch 00049: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1458 - val_loss: 1.2189
# Epoch 50/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1228
# Epoch 00050: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1218 - val_loss: 1.2167
# Epoch 51/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1005
# Epoch 00051: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1195 - val_loss: 1.2196
# Epoch 52/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1088
# Epoch 00052: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1210 - val_loss: 1.2183
# Epoch 53/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1319
# Epoch 00053: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1168 - val_loss: 1.2723
# Epoch 54/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1404
# Epoch 00054: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1441 - val_loss: 1.2335
# Epoch 55/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1305
# Epoch 00055: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1191 - val_loss: 1.2127
# Epoch 56/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1014
# Epoch 00056: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1210 - val_loss: 1.2124
# Epoch 57/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1231
# Epoch 00057: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1269 - val_loss: 1.2213
# Epoch 58/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1217
# Epoch 00058: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1183 - val_loss: 1.2105
# Epoch 59/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1271
# Epoch 00059: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1240 - val_loss: 1.2113
# Epoch 60/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1079
# Epoch 00060: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1117 - val_loss: 1.2160
# Epoch 61/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1298
# Epoch 00061: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1138 - val_loss: 1.2122
# Epoch 62/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1025
# Epoch 00062: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1157 - val_loss: 1.2214
# Epoch 63/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1466
# Epoch 00063: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1266 - val_loss: 1.2065
# Epoch 64/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1111
# Epoch 00064: val_loss did not improve from 1.20609
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1109 - val_loss: 1.2068
# Epoch 65/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0988
# Epoch 00065: val_loss improved from 1.20609 to 1.19872, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1121 - val_loss: 1.1987
# Epoch 66/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1153
# Epoch 00066: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1286 - val_loss: 1.2248
# Epoch 67/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1095
# Epoch 00067: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1097 - val_loss: 1.2719
# Epoch 68/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1401
# Epoch 00068: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1424 - val_loss: 1.2254
# Epoch 69/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1468
# Epoch 00069: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1403 - val_loss: 1.2081
# Epoch 70/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0966
# Epoch 00070: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1190 - val_loss: 1.2011
# Epoch 71/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1198
# Epoch 00071: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1118 - val_loss: 1.2463
# Epoch 72/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0937
# Epoch 00072: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1090 - val_loss: 1.2140
# Epoch 73/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0946
# Epoch 00073: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1044 - val_loss: 1.2176
# Epoch 74/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0727
# Epoch 00074: val_loss did not improve from 1.19872
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1073 - val_loss: 1.2119
# Epoch 75/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1139
# Epoch 00075: val_loss improved from 1.19872 to 1.19517, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.1063 - val_loss: 1.1952
# Epoch 76/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1159
# Epoch 00076: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1043 - val_loss: 1.2357
# Epoch 77/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1095
# Epoch 00077: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1214 - val_loss: 1.2189
# Epoch 78/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1032
# Epoch 00078: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0989 - val_loss: 1.2661
# Epoch 79/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0673
# Epoch 00079: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1171 - val_loss: 1.2354
# Epoch 80/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0804
# Epoch 00080: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1042 - val_loss: 1.2220
# Epoch 81/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1034
# Epoch 00081: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1002 - val_loss: 1.1955
# Epoch 82/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1183
# Epoch 00082: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.1045 - val_loss: 1.2095
# Epoch 83/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0967
# Epoch 00083: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0908 - val_loss: 1.2011
# Epoch 84/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1206
# Epoch 00084: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1303 - val_loss: 1.2083
# Epoch 85/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1017
# Epoch 00085: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0911 - val_loss: 1.2091
# Epoch 86/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1057
# Epoch 00086: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.1049 - val_loss: 1.1959
# Epoch 87/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.1059
# Epoch 00087: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0966 - val_loss: 1.1967
# Epoch 88/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0940
# Epoch 00088: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0813 - val_loss: 1.1996
# Epoch 89/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0836
# Epoch 00089: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0758 - val_loss: 1.1992
# Epoch 90/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0867
# Epoch 00090: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0920 - val_loss: 1.2033
# Epoch 91/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0544
# Epoch 00091: val_loss did not improve from 1.19517
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0841 - val_loss: 1.1964
# Epoch 92/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0826
# Epoch 00092: val_loss improved from 1.19517 to 1.18491, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0790 - val_loss: 1.1849
# Epoch 93/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0689
# Epoch 00093: val_loss did not improve from 1.18491
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0716 - val_loss: 1.2067
# Epoch 94/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0756
# Epoch 00094: val_loss improved from 1.18491 to 1.17553, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0753 - val_loss: 1.1755
# Epoch 95/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0799- ETA: 0s - los
# Epoch 00095: val_loss did not improve from 1.17553
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0722 - val_loss: 1.1934
# Epoch 96/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0493
# Epoch 00096: val_loss improved from 1.17553 to 1.17309, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0673 - val_loss: 1.1731
# Epoch 97/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0669
# Epoch 00097: val_loss did not improve from 1.17309
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0558 - val_loss: 1.1823
# Epoch 98/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0452
# Epoch 00098: val_loss did not improve from 1.17309
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0368 - val_loss: 1.2007
# Epoch 99/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0787
# Epoch 00099: val_loss improved from 1.17309 to 1.17095, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.0667 - val_loss: 1.1710
# Epoch 100/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0538
# Epoch 00100: val_loss improved from 1.17095 to 1.17090, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.0456 - val_loss: 1.1709
# Epoch 101/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0588
# Epoch 00101: val_loss did not improve from 1.17090
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0349 - val_loss: 1.1909
# Epoch 102/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0392
# Epoch 00102: val_loss did not improve from 1.17090
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0376 - val_loss: 1.1797
# Epoch 103/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0151
# Epoch 00103: val_loss did not improve from 1.17090
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0321 - val_loss: 1.2245
# Epoch 104/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0601
# Epoch 00104: val_loss did not improve from 1.17090
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0424 - val_loss: 1.2339
# Epoch 105/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0087
# Epoch 00105: val_loss improved from 1.17090 to 1.17060, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 14ms/sample - loss: 1.0355 - val_loss: 1.1706
# Epoch 106/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0043
# Epoch 00106: val_loss improved from 1.17060 to 1.16226, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0146 - val_loss: 1.1623
# Epoch 107/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0141
# Epoch 00107: val_loss improved from 1.16226 to 1.14399, saving model to C:\Users\icecr\Desktop\downloads\model_1.h5
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0190 - val_loss: 1.1440
# Epoch 108/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0442
# Epoch 00108: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0323 - val_loss: 1.1766
# Epoch 109/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0248
# Epoch 00109: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0205 - val_loss: 1.1848
# Epoch 110/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0121
# Epoch 00110: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0100 - val_loss: 1.1913
# Epoch 111/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.0233
# Epoch 00111: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0296 - val_loss: 1.1800
# Epoch 112/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9904
# Epoch 00112: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 1.0094 - val_loss: 1.1601
# Epoch 113/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9986
# Epoch 00113: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 1.0044 - val_loss: 1.2605
# Epoch 114/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9824
# Epoch 00114: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9770 - val_loss: 1.3024
# Epoch 115/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9893
# Epoch 00115: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9782 - val_loss: 1.1900
# Epoch 116/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9830
# Epoch 00116: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9821 - val_loss: 1.2388
# Epoch 117/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9448
# Epoch 00117: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9502 - val_loss: 1.1730
# Epoch 118/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9612
# Epoch 00118: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9511 - val_loss: 1.3922
# Epoch 119/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9372
# Epoch 00119: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9303 - val_loss: 1.2030
# Epoch 120/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9564
# Epoch 00120: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.9599 - val_loss: 1.3181
# Epoch 121/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9333
# Epoch 00121: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.9221 - val_loss: 1.2141
# Epoch 122/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9030
# Epoch 00122: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.8972 - val_loss: 1.3153
# Epoch 123/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.9073
# Epoch 00123: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.8902 - val_loss: 1.3205
# Epoch 124/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8876
# Epoch 00124: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.8808 - val_loss: 1.3863
# Epoch 125/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8844
# Epoch 00125: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.8748 - val_loss: 1.5845
# Epoch 126/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8444
# Epoch 00126: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.8714 - val_loss: 1.3421
# Epoch 127/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8736
# Epoch 00127: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.8731 - val_loss: 1.3766
# Epoch 128/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8538
# Epoch 00128: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.8486 - val_loss: 1.2141
# Epoch 129/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8352
# Epoch 00129: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.8330 - val_loss: 1.3980
# Epoch 130/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8255
# Epoch 00130: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.8152 - val_loss: 1.3178
# Epoch 131/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8196
# Epoch 00131: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.8161 - val_loss: 1.3253
# Epoch 132/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8072
# Epoch 00132: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.8106 - val_loss: 1.2617
# Epoch 133/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.8021
# Epoch 00133: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.7918 - val_loss: 1.4666
# Epoch 134/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.7634
# Epoch 00134: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.7640 - val_loss: 1.7967
# Epoch 135/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.7451
# Epoch 00135: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.7613 - val_loss: 1.4695
# Epoch 136/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.7428
# Epoch 00136: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.7413 - val_loss: 1.4230
# Epoch 137/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.7693
# Epoch 00137: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.7608 - val_loss: 1.6284
# Epoch 138/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.7444
# Epoch 00138: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.7369 - val_loss: 1.5102
# Epoch 139/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6805
# Epoch 00139: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6950 - val_loss: 1.5849
# Epoch 140/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6961
# Epoch 00140: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.6974 - val_loss: 1.4049
# Epoch 141/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.7187
# Epoch 00141: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.7034 - val_loss: 1.5580
# Epoch 142/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6899
# Epoch 00142: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6806 - val_loss: 1.7507
# Epoch 143/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6570
# Epoch 00143: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6686 - val_loss: 1.6973
# Epoch 144/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6479
# Epoch 00144: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6486 - val_loss: 1.7095
# Epoch 145/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6406
# Epoch 00145: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6385 - val_loss: 1.8283
# Epoch 146/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6290
# Epoch 00146: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6246 - val_loss: 1.9585
# Epoch 147/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6313
# Epoch 00147: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6272 - val_loss: 1.6909
# Epoch 148/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6407
# Epoch 00148: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6388 - val_loss: 2.0939
# Epoch 149/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6381
# Epoch 00149: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6283 - val_loss: 1.9079
# Epoch 150/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6486
# Epoch 00150: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6474 - val_loss: 1.6824
# Epoch 151/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.6166
# Epoch 00151: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.6170 - val_loss: 1.8314
# Epoch 152/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5720
# Epoch 00152: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5734 - val_loss: 1.8922
# Epoch 153/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5697
# Epoch 00153: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5689 - val_loss: 2.1451
# Epoch 154/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5486
# Epoch 00154: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.5614 - val_loss: 1.8849
# Epoch 155/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5707
# Epoch 00155: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5654 - val_loss: 1.9633
# Epoch 156/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5481
# Epoch 00156: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5519 - val_loss: 1.9353
# Epoch 157/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5374
# Epoch 00157: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5301 - val_loss: 2.1556
# Epoch 158/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5107
# Epoch 00158: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5101 - val_loss: 2.1964
# Epoch 159/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5248
# Epoch 00159: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5171 - val_loss: 1.9693
# Epoch 160/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5100
# Epoch 00160: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5053 - val_loss: 2.0890
# Epoch 161/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5115
# Epoch 00161: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5150 - val_loss: 2.0184
# Epoch 162/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5033
# Epoch 00162: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5146 - val_loss: 2.0887
# Epoch 163/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4823
# Epoch 00163: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4807 - val_loss: 2.2165
# Epoch 164/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4764
# Epoch 00164: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4775 - val_loss: 2.2429
# Epoch 165/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5043
# Epoch 00165: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4995 - val_loss: 2.0656
# Epoch 166/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5406
# Epoch 00166: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5328 - val_loss: 2.0646
# Epoch 167/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5232
# Epoch 00167: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5204 - val_loss: 1.9990
# Epoch 168/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5141
# Epoch 00168: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5053 - val_loss: 2.0984
# Epoch 169/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5229
# Epoch 00169: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5180 - val_loss: 1.9875
# Epoch 170/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5601
# Epoch 00170: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5495 - val_loss: 1.7593
# Epoch 171/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5516
# Epoch 00171: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5545 - val_loss: 2.6481
# Epoch 172/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.5394
# Epoch 00172: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.5342 - val_loss: 1.9521
# Epoch 173/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4606
# Epoch 00173: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4506 - val_loss: 2.1430
# Epoch 174/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4369
# Epoch 00174: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4338 - val_loss: 2.2061
# Epoch 175/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4099
# Epoch 00175: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4172 - val_loss: 2.2585
# Epoch 176/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4104
# Epoch 00176: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4070 - val_loss: 2.2675
# Epoch 177/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3900
# Epoch 00177: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3936 - val_loss: 2.3336
# Epoch 178/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4129
# Epoch 00178: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4114 - val_loss: 2.3070
# Epoch 179/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4258
# Epoch 00179: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4320 - val_loss: 2.4887
# Epoch 180/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4221
# Epoch 00180: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4223 - val_loss: 2.3589
# Epoch 181/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4063
# Epoch 00181: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3965 - val_loss: 2.3214
# Epoch 182/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3714
# Epoch 00182: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3639 - val_loss: 2.3369
# Epoch 183/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3504
# Epoch 00183: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3505 - val_loss: 2.3858
# Epoch 184/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3427
# Epoch 00184: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3490 - val_loss: 2.2398
# Epoch 185/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3696
# Epoch 00185: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3704 - val_loss: 2.3621
# Epoch 186/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3731
# Epoch 00186: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3782 - val_loss: 2.5574
# Epoch 187/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3866
# Epoch 00187: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3883 - val_loss: 2.3570
# Epoch 188/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3768
# Epoch 00188: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3837 - val_loss: 2.1457
# Epoch 189/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3755
# Epoch 00189: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3812 - val_loss: 2.3668
# Epoch 190/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.4008
# Epoch 00190: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.4020 - val_loss: 2.4821
# Epoch 191/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3714
# Epoch 00191: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3829 - val_loss: 2.4937
# Epoch 192/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3612
# Epoch 00192: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3563 - val_loss: 2.1564
# Epoch 193/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3434
# Epoch 00193: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3422 - val_loss: 2.4532
# Epoch 194/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3365
# Epoch 00194: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3450 - val_loss: 2.5004
# Epoch 195/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3328
# Epoch 00195: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3281 - val_loss: 2.6645
# Epoch 196/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3135
# Epoch 00196: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3138 - val_loss: 2.5454
# Epoch 197/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3161
# Epoch 00197: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3101 - val_loss: 2.5099
# Epoch 198/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3246
# Epoch 00198: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3202 - val_loss: 2.5454
# Epoch 199/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3192
# Epoch 00199: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3185 - val_loss: 2.2809
# Epoch 200/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3254
# Epoch 00200: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3189 - val_loss: 2.6186
# Epoch 201/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3344
# Epoch 00201: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3313 - val_loss: 2.4822
# Epoch 202/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3658
# Epoch 00202: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3779 - val_loss: 2.5489
# Epoch 203/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3596
# Epoch 00203: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3564 - val_loss: 2.6068
# Epoch 204/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3183
# Epoch 00204: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3129 - val_loss: 2.5142
# Epoch 205/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2890
# Epoch 00205: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.2975 - val_loss: 2.6061
# Epoch 206/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3277
# Epoch 00206: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3280 - val_loss: 2.4220
# Epoch 207/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3244
# Epoch 00207: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3237 - val_loss: 2.9440
# Epoch 208/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3184
# Epoch 00208: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3253 - val_loss: 2.4108
# Epoch 209/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3253
# Epoch 00209: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.3344 - val_loss: 2.3927
# Epoch 210/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.3018
# Epoch 00210: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.2994 - val_loss: 2.3842
# Epoch 211/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2522
# Epoch 00211: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.2576 - val_loss: 2.5330
# Epoch 212/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2560
# Epoch 00212: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.2630 - val_loss: 2.5782
# Epoch 213/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2476
# Epoch 00213: val_loss did not improve from 1.14399
# ...
# Epoch 428/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0416
# Epoch 00428: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0458 - val_loss: 3.0567
# Epoch 429/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0671
# Epoch 00429: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0665 - val_loss: 3.0381
# Epoch 430/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0743
# Epoch 00430: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0726 - val_loss: 3.1386
# Epoch 431/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0756
# Epoch 00431: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0757 - val_loss: 3.0537
# Epoch 432/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1056
# Epoch 00432: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1063 - val_loss: 2.9591
# Epoch 433/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0676
# Epoch 00433: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0723 - val_loss: 3.0360
# Epoch 434/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0672
# Epoch 00434: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0666 - val_loss: 3.0104
# Epoch 435/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0591
# Epoch 00435: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0593 - val_loss: 3.0687
# Epoch 436/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0690
# Epoch 00436: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0675 - val_loss: 3.0644
# Epoch 437/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0488
# Epoch 00437: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0491 - val_loss: 3.0822
# Epoch 438/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0468
# Epoch 00438: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0466 - val_loss: 3.1930
# Epoch 439/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00439: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0435 - val_loss: 3.1501
# Epoch 440/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0526
# Epoch 00440: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0515 - val_loss: 3.1078
# Epoch 441/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0424
# Epoch 00441: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0427 - val_loss: 3.2055
# Epoch 442/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0382
# Epoch 00442: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0374 - val_loss: 3.1977
# Epoch 443/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0370
# Epoch 00443: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0363 - val_loss: 3.1761
# Epoch 444/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0341
# Epoch 00444: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0354 - val_loss: 3.2279
# Epoch 445/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0352
# Epoch 00445: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0347 - val_loss: 3.2259
# Epoch 446/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0296
# Epoch 00446: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0298 - val_loss: 3.2793
# Epoch 447/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0295
# Epoch 00447: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0293 - val_loss: 3.3215
# Epoch 448/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0323
# Epoch 00448: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0320 - val_loss: 3.2721
# Epoch 449/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0338
# Epoch 00449: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0330 - val_loss: 3.2344
# Epoch 450/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0352
# Epoch 00450: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0352 - val_loss: 3.3085
# Epoch 451/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0344
# Epoch 00451: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0346 - val_loss: 3.2267
# Epoch 452/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0259
# Epoch 00452: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0296 - val_loss: 3.3092
# Epoch 453/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00453: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0369 - val_loss: 3.3349
# Epoch 454/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0394
# Epoch 00454: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0391 - val_loss: 3.2606
# Epoch 455/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0397
# Epoch 00455: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0393 - val_loss: 3.2758
# Epoch 456/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0414
# Epoch 00456: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0415 - val_loss: 3.1927
# Epoch 457/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0568
# Epoch 00457: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0588 - val_loss: 3.1712
# Epoch 458/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0716
# Epoch 00458: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0709 - val_loss: 3.0880
# Epoch 459/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0767
# Epoch 00459: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0785 - val_loss: 3.1765
# Epoch 460/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0744
# Epoch 00460: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0743 - val_loss: 3.1576
# Epoch 461/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1479
# Epoch 00461: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1439 - val_loss: 3.0015
# Epoch 462/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0873
# Epoch 00462: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0868 - val_loss: 3.2055
# Epoch 463/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0690
# Epoch 00463: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0684 - val_loss: 3.1330
# Epoch 464/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0472
# Epoch 00464: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0463 - val_loss: 3.0662
# Epoch 465/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00465: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0360 - val_loss: 3.2308
# Epoch 466/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0383
# Epoch 00466: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0379 - val_loss: 3.2417
# Epoch 467/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0376
# Epoch 00467: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0371 - val_loss: 3.2913
# Epoch 468/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0406
# Epoch 00468: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0410 - val_loss: 3.2540
# Epoch 469/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0310
# Epoch 00469: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0306 - val_loss: 3.2717
# Epoch 470/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0331
# Epoch 00470: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0325 - val_loss: 3.2028
# Epoch 471/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0364
# Epoch 00471: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0357 - val_loss: 3.2160
# Epoch 472/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0289
# Epoch 00472: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0296 - val_loss: 3.1901
# Epoch 473/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0287
# Epoch 00473: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0297 - val_loss: 3.2855
# Epoch 474/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0281
# Epoch 00474: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0295 - val_loss: 3.1534
# Epoch 475/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0936
# Epoch 00475: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0925 - val_loss: 3.0631
# Epoch 476/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0712
# Epoch 00476: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0839 - val_loss: 3.0972
# Epoch 477/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1518
# Epoch 00477: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1550 - val_loss: 2.7816
# Epoch 478/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.2748
# Epoch 00478: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.2828 - val_loss: 1.9289
# Epoch 479/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1837
# Epoch 00479: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.1803 - val_loss: 2.7950
# Epoch 480/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1225
# Epoch 00480: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.1256 - val_loss: 3.0030
# Epoch 481/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0685
# Epoch 00481: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0669 - val_loss: 3.0722
# Epoch 482/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0680
# Epoch 00482: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0681 - val_loss: 3.1487
# Epoch 483/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0525
# Epoch 00483: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0515 - val_loss: 2.9902
# Epoch 484/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0503
# Epoch 00484: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0501 - val_loss: 3.0473
# Epoch 485/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0521
# Epoch 00485: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0518 - val_loss: 3.1135
# Epoch 486/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0404
# Epoch 00486: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0398 - val_loss: 3.0760
# Epoch 487/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0326
# Epoch 00487: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0325 - val_loss: 3.0801
# Epoch 488/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0290
# Epoch 00488: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0288 - val_loss: 3.0870
# Epoch 489/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0256
# Epoch 00489: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0263 - val_loss: 3.1444
# Epoch 490/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0252
# Epoch 00490: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0251 - val_loss: 3.1662
# Epoch 491/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0310
# Epoch 00491: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0304 - val_loss: 3.1920
# Epoch 492/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0460
# Epoch 00492: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 13ms/sample - loss: 0.0450 - val_loss: 3.2482
# Epoch 493/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0609
# Epoch 00493: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0649 - val_loss: 3.0921
# Epoch 494/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1607
# Epoch 00494: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1578 - val_loss: 2.8407
# Epoch 495/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1062
# Epoch 00495: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1099 - val_loss: 3.1813
# Epoch 496/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.1243
# Epoch 00496: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.1254 - val_loss: 2.8306
# Epoch 497/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0950
# Epoch 00497: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0982 - val_loss: 2.8343
# Epoch 498/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0683
# Epoch 00498: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0674 - val_loss: 2.9560
# Epoch 499/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0628
# Epoch 00499: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0620 - val_loss: 3.0940
# Epoch 500/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0459
# Epoch 00500: val_loss did not improve from 1.14399
# 90/90 [==============================] - 1s 12ms/sample - loss: 0.0465 - val_loss: 3.0635

# %%
pred = model.predict(DATASET_IMG[:1])
print(pred.shape)
display_multiple_img(pred[0], VOC_CLASSES, 3, 7)
# Out:
# (1, 256, 256, 21)

# %%
display_multiple_img(DATASET_SEG_MASK[0], VOC_CLASSES, 3, 7)

# %%
sample_vec = pred[0][200][220]
print(sample_vec.shape)
print(sample_vec)
np.argmax(sample_vec)

# %%
np.sum(pred[0][0][0])

# %%
sum(pred[0][0][1])

# %%
sum(pred[0][0][2])

# %%
plt.imshow(DATASET_IMG[2])

# %%
from tensorflow.keras import layers
from tensorflow import keras
img_size = (256, 256)
num_classes = 21
batch_size = 3
def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %%
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_model(img_size, num_classes)
model.summary()
